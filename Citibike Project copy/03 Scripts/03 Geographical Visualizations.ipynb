# %% [markdown]
# # Import Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import os
import folium
import json

# %%
# %matplotlib inline

# %%
# Import ".json" file for the U.S. 
country_geo = r'/Users/mimielaurant/Documents/Career Foundry/Immersion_Achievement 6/Citibike Project/02 Data/Original Data/new-york-city-boroughs-ny_.geojson'

# %%
# define path
path = '/Users/mimielaurant/Documents/Career Foundry/Immersion_Achievement 6/Citibike Project'

# %%
# import citibike_clean.csv
data = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'citibikes_clean.csv'), index_col = False)

# %%
data.head()
# Out:
#    Unnamed: 0 trip_id  bike_id weekday  start_hour           start_time  \
# 0           0  LnQzQk    16013     Mon          18  2013-09-09 18:18:55
# 1           1  IL9boN    15230     Thu          18  2013-09-12 18:38:53
# 2           2  46clGB    17942     Wed          19  2013-09-18 19:44:04
# 3           3  v7vdFt    19683     Sat          11  2013-09-28 11:54:37
# 4           4  VGBsb5    18024     Sat          18  2013-09-07 18:08:22
#
#    start_station_id       start_station_name  start_station_latitude  \
# 0               523          W 38 St & 8 Ave               40.754666
# 1               257  Lispenard St & Broadway               40.719392
# 2               479          9 Ave & W 45 St               40.760193
# 3               527          E 33 St & 1 Ave               40.743156
# 4               521          8 Ave & W 31 St               40.750450
#
#    start_station_longitude  ... end_station_id     end_station_name  \
# ...

# %%
data.shape
# Out:
# (49977, 21)

# %% [markdown]
# # Wrangling Data

# %%
# create locationslist dataframe for map markers
locations = data[['start_station_latitude', 'start_station_longitude']]

# %%
# locate duplicates
loc_dups = locations[locations.duplicated()]

# %%
loc_dups
# Out:
#        start_station_latitude  start_station_longitude
# 23                  40.734011               -74.002939
# 32                  40.744876               -73.995299
# 36                  40.763441               -73.982681
# 37                  40.754666               -73.991382
# 48                  40.732264               -73.998522
# ...                       ...                      ...
# 49972               40.760193               -73.991255
# 49973               40.694749               -73.983625
# 49974               40.740343               -73.989551
# 49975               40.685282               -73.978058
# 49976               40.760094               -73.994618
#
# [49647 rows x 2 columns]

# %%
locations.shape
# Out:
# (49977, 2)

# %%
# remove duplicates from locations dataframe
locations_clean = locations.drop_duplicates()

# %%
locations_clean.shape
# Out:
# (330, 2)

# %%
# create locations list
locationlist = locations_clean.values.tolist()
len(locationlist)
locationlist[7]
# Out:
# [40.73652889, -74.00618026]

# %% [markdown]
# # Generating a map using Folium

# %%
map = folium.Map(location=[40.712776, -74.005974], zoom_start=12)
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=data['start_station_name'][point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map.save(os.path.join(path, '04 Analysis', 'Visualizations', 'NYC_map.html'))
